# %% [markdown]
# # Tabular Text Method
# We wanted to see how well the classifier would do if we included additional information about dates. Since the model's performance didn't increase significantly and this method did not involve an easy way to export our model, we decided not to use it.
#
# This is the repo that contains the source code for this method: https://github.com/anhquan0412/fastai-tabular-text-demo/blob/master/fastai_tabtext2.py. The tab-text method was developed by Github user anhquan0412.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *
from fastai.tabular import *
from fastai_tabtext2 import *
from fastai_tab_text import *
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from sklearn.model_selection import KFold

# %%
def reset_seed(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
reset_seed()

# %%
gc.collect()
# Out:
# 0

# %%
def get_val_idxs(train,n_splits=20):
    np.random.seed(42)
    cv = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    train_idxs, valid_idxs = next(cv.split(train))
    return train_idxs,valid_idxs

# %%
train_df = pd.read_csv('train.csv')
train = train_df.sample(int(len(train_df)*0.01)) # 5% of training set
print("printing number of documents in subset: {}".format(len(train)))
# Out:
# printing number of documents in subset: 2735

# %%
test_df = pd.read_csv('test.csv')
test = test_df.sample(int(len(test_df)*0.01))
print("printing number of documents in subset: {}".format(len(test)))
# Out:
# printing number of documents in subset: 681

# %%
train_df['school'] = train_df['school'].str.replace('Closed', '') # parse out closed label from school name

# %%
test_df['school'] = test_df['school'].str.replace('Closed', '') # parse out closed label from school name

# %%
print ("printing len of train_df: {}".format(len(train_df)))
print ("printing len of test_df: {}".format(len(test_df)))
# Out:
# printing len of train_df: 273517
# printing len of test_df: 68166

# %%
train_df = train_df[train_df.date != ' ']
test_df = test_df[test_df.date != ' '] # remove entries with missing dates

# %%
train_df = train_df[train_df['school'].str.contains('[a-zA-Z]')]
test_df = test_df[test_df['school'].str.contains('[a-zA-Z]')]

# %%
print ("printing len of train_df after dropping: {}".format(len(train_df)))
print ("printing len of test_df after dropping: {}".format(len(test_df)))
# Out:
# printing len of train_df after dropping: 185548
# printing len of test_df after dropping: 46356

# %%
print("number of closed schools in train_df: {}".format(len(train_df[train_df['label'] == 'closed'])))
print("number of open schools in train_df: {}".format(len(train_df[train_df['label'] == 'open'])))
# Out:
# number of closed schools in train_df: 50846
# number of open schools in train_df: 134702

# %%
print("number of closed schools in test_df: {}".format(len(test_df[test_df['label'] == 'closed'])))
print("number of open schools in test_df: {}".format(len(test_df[test_df['label'] == 'open'])))
# Out:
# number of closed schools in test_df: 12875
# number of open schools in test_df: 33481

# %%
gc.collect()
# Out:
# 60

# %%
train.shape, test.shape
# Out:
# ((2735, 5), (681, 5))

# %%
train.columns
# Out:
# Index(['school', 'text', 'label', 'file', 'date'], dtype='object')

# %%
train['school'] = train['school'].str.replace('Closed', '') # parse out closed label from school name

# %%
train = train[train.date != ' '] # remove entries with missing dates

# %%
mapping = {'closed': 0, 'open': 1}
train = train.applymap(lambda s: mapping.get(s) if s in mapping else s)

# %%
train.head()
# Out:
#                                           school  \
# 137283                       Trench Tots Nursery
# 114283  St Joseph's Catholic Primary School, SWF
# 45273                Cheveley Acorns Pre School
# 163090                             URN: SC066393
# 208159                  Whittington Green School
#
#                                                      text  label      file  \
# 137283  COMBINED INSPECTION REPORTURN EY      DfES Num...      1   1587885
# 114283       Piccadilly Gate Store Street Manchester M...      1  50021735
# 45273       Cheveley Acorns Pre School    Cheveley Aco...      0   2738269
# 163090         s home  SC            SC       Register...      1   2762627
# 208159    School report   The Meadows Community School...      1   2183749
#
#                      date
# 137283   16 December 2009
# 114283       05 July 2018
# 45273       24 March 2018
# 163090   28 December 2018
# 208159  29 September 2014

# %%
test['file'] = pd.to_numeric(test['file'])

# %%
train['school'] = train['school'].str.replace('Closed', '') # parse out closed label from school name

# %%
test = test[test.date != ' '] # remove entries with missing dates

# %%
test = test.applymap(lambda s: mapping.get(s) if s in mapping else s)

# %%
test.head()
# Out:
#                                                   school  \
# 2213                       Moat Street Pre-School Closed
# 18797  Cirencester Opportunity Group registration unt...
# 65889                                  Marvel Pre-School
# 48600                     Magic Roundabout Nurseries Ltd
# 65254                        Squirrel Hayes First School
#
#                                                     text  label     file  \
# 2213   UntitledMoat Street Pre School for s provision...      0  1093911
# 18797  UntitledCencester Opportunity Group for s prov...      0  1138249
# 65889  UntitledMarvel After School Club for s provisi...      1  1061613
# 48600      Magic Roundabout Nurseries Limited       S...      1  2542206
# 65254  Page   of     December      Mrs J BettsThe Hea...      1   907807
#
#                     date
# 2213     05 January 2012
# 18797  29 September 2011
# 65889   09 November 2012
# 48600     26 August 2016
# 65254   10 December 2008

# %%
train = train[train['school'].str.contains('[a-zA-Z]')]

# %%
print("printing number of documents in train after dropping : {}".format(len(train)))
# Out:
# printing number of documents in train after dropping : 1826

# %%
print("number of closed schools in train: {}".format(len(train[train['label'] == 0])))
print("number of open schools in train: {}".format(len(train[train['label'] == 1])))
# Out:
# number of closed schools in train: 507
# number of open schools in train: 1319

# %%
test = test[test['school'].str.contains('[a-zA-Z]')]

# %%
print ("number of closed schools in test: {}".format(len(test[test['label'] == 0])))
print ("number of open schools in test: {}".format(len(test[test['label'] == 1])))
# Out:
# number of closed schools in test: 154
# number of open schools in test: 314

# %%
print("printing number of documents in train after dropping : {}".format(len(test)))
# Out:
# printing number of documents in train after dropping : 468

# %%
train.to_csv('sample_train.csv')

# %%
test.to_csv('sample_test.csv')

# %%
add_datepart(train, 'date', drop=True)
# Out:
#       Unnamed: 0                                             school  \
# 0         137283                                Trench Tots Nursery
# 1         114283           St Joseph's Catholic Primary School, SWF
# 2          45273                        Cheveley Acorns Pre School
# 3         163090                                      URN: SC066393
# 4         208159                           Whittington Green School
# 5          69940                                 Kinder Kapers Too
# 6         205694                              Michelle Linzi Judson
# 7          78626         Masham Church of England VA Primary School
# 8         112739                            Hawkedon Primary School
# 9          73060                   New Haw Community Junior School
# 10        145302                                  Intake Pre School
# 11        198539                             West Berkshire Council
# 12        113972                     Hope Brook CofE Primary School
# 13        238080                                  Preschool@stmarks
# 14        247865                                      URN: SC033127
# 15        221964           Sarum St Paul's CofE (VA) Primary School
# 16         25554                         Tiny Toes Day Nursery Ltd
# 17        121447               St Aidan's Church of England Academy
# 18        101198                            Frederick Bremer School
# 19        217839  Scole Church of England Voluntary Controlled P...
# 20        239805      Veolia Environment Development Centre Limited
# 21         43282                Kingston  Pre-School & Day Nursery
# 22        140331                                Glebe Junior School
# 7             False  1332201600
# 8             False  1537920000
# 9             False  1238544000
# 10            False  1389139200
# 11            False  1363824000
# 12            False  1395964800
# 13            False  1530230400
# 14            False  1395792000
# 15            False  1326067200
# 16            False  1434067200
# 17            False  1430352000
# 18            False  1380067200
# 19            False  1497571200
# 20            False  1489968000
# 21            False  1368835200
# 22            False  1351123200
# 23            False  1326067200
# 24            False  1261699200
# 25            False  1477958400
# 26            False  1358208000
# 27            False  1354060800
# 28            False  1538611200
# 29            False  1513036800
# ...             ...         ...
# 1796          False  1446595200
# 1797          False  1461196800
# 1798          False  1403136000
# 1799          False  1525824000
# 1800          False  1332892800
# 1801          False  1394409600
# 1802          False  1544054400
# 1803          False  1449532800
# 1804          False  1531094400
# 1805          False  1452729600
# 1806          False  1358208000
# 1807          False  1423526400
# 1808          False  1258675200
# 1809          False  1372291200
# 1810          False  1499817600
# 1811          False  1379289600
# 1812          False  1427760000
# 1813          False  1383955200
# 1814          False  1297296000
# 1815          False  1461888000
# 1816          False  1382400000
# 1817          False  1289174400
# 1818          False  1433289600
# 1819          False  1423526400
# 1820          False  1447286400
# 1821          False  1511827200
# 1822          False  1359936000
# 1823          False  1406937600
# 1824          False  1447632000
# 1825          False  1530144000
#
# [1826 rows x 18 columns]

# %%
add_datepart(test, 'date', drop=True)
# Out:
#      Unnamed: 0                                             school  \
# 0          2213                      Moat Street Pre-School Closed
# 1         18797  Cirencester Opportunity Group registration unt...
# 2         65889                                  Marvel Pre-School
# 3         48600                     Magic Roundabout Nurseries Ltd
# 4         65254                        Squirrel Hayes First School
# 5         44572                                      URN: EY475333
# 6         51104                           Eyam CofE Primary School
# 7         28472   St Benedict's Primary Catholic Voluntary Academy
# 8         32561                         Royal School for the Blind
# 9         41561                           London Borough of Ealing
# 10        24966                                      URN: SC480705
# 11        67488                                    Stepping Stones
# 12        45795  St Matthew's Church of England Aided Primary S...
# 13        34910                                   Pavilion Project
# 14        13143                                     The Den Closed
# 15        47300                                      URN: SC008607
# 16         9720                               URN: EY363611 Closed
# 17        13568  Inverteign Community Nursery and Primary Schoo...
# 18        38318                                    Holyhead School
# 19        38988                         Frimley CofE Junior School
# 20        60733               Newdigate Primary and Nursery School
# 21        21294                              Little MarVals Closed
# 22         5623                               URN: EY332098 Closed
# 23        59099                Hallcroft Infant and Nursery School
# 24        38238                                   Lymm High School
# 25        23868                               URN: EY287910 Closed
# 26        47997                               Little Joeys Nursery
# 27         3367  The Nettleham Church of England Voluntary Aide...
# 28        21187         Witherley Church of England Primary School
# 29        62041                            Westways Primary School
# ..          ...                                                ...
# 438       20372                   Wilmington Primary School Closed
# 439       14192                   Avenue Kids Club (A.K.C.) Closed
# 440        9142                      Moulton Chapel Primary School
# 441       47394                       Staffordshire County Council
# 442       45953                        Great Leighs Primary School
# 443       17598                         Nic-Bec Day Nursery Closed
# 444        4747    The Eldon Federation Eldon Junior School Closed
# 445       33873               St Theresa's Catholic Primary School
# 446       51256                          Whipperley Infant Academy
# 447        8331  The Lawns Nursery School and Children's Centre...
# 448       58862                                   Sunnydown School
# 449       52195                    St Andrew's CofE Primary School
# 450       26648                       Little Angels Nursery School
# 451       11525                          Marwood Pre-School Closed
# 452       17183                   Dormers Wells High School Closed
# 453       11322             Lancaster Girls' Grammar School Closed
# 454       14576            Brackley Waynflete Infant School Closed
# 455       61210                   Newton Poppleford Primary School
# 456       10040                           Kingsfold Primary School
# 457        9721                 Maeda Gakuen: Acton Yochien Closed
# 458       45772                St Paulinus Catholic Primary School
# 459       20180                    Westfield Primary School Closed
# 460       22983                       Bradley Green Nursery Closed
# 461       47870              MASK (Mossley After School Club) Ltd.
# 462       44918       Mytime Active – Kent House After School Club
# 463       54453                             Tarrant, Caroline Jane
# 464       60756                        Southchurch Park Pre School
# 465       32816                                      URN: SC065261
# 466       29061                            Heathrow Primary School
# 467       63451                           Sandhurst Nursery School
#
#                                                   text  label      file  Year  \
# 0    UntitledMoat Street Pre School for s provision...      0   1093911  2012
# 1    UntitledCencester Opportunity Group for s prov...      0   1138249  2011
# 2    UntitledMarvel After School Club for s provisi...      1   1061613  2012
# 3        Magic Roundabout Nurseries Limited       S...      1   2542206  2016
# 4    Page   of     December      Mrs J BettsThe Hea...      1    907807  2008
# 5    Complaint about childcare provisionRef  EY    ...      1  50053465  2019
# 6    UntitledEyam CofE Primary School      Unique R...      1    924729  2014
# 7     School report      St Benedict s Primary Cath...      1   2780423  2018
# 8     Residential report    Royal School for  Blind...      1   2454382  2017
# 9    OVERALL RATINGCurrent PerformanceIndications o...      1  50002632  2005
# 10          s home  SC             SC       Registe...      1   2686505  2018
# 11       Stepping Stones    Stanley Peters Junior  ...      1   2549608  2018
# 12   School report       St Matw s CofE Primary Sch...      1   2577085  2016
# 13       Pavilion Project    The Hub  Derwent Stree...      1   2608303  2016
# 14   UntitledThe Den for s provisionEY      Unique ...      0   1198141  2011
# 15               for  s home   Unique reference num...      1   2180383  2015
# 16   Untitled for s provisionEY      Unique Referen...      0   1198809  2015
# 17   UntitledInverteign Community Nursery andPrimar...      0    907283  2010
# 18        Mr M Bayliss Holyhead School Milestone La...      1   2479267  2018
# 19          PDFINSPECTION REPORTFRIMLEY C of E JUNI...      1    789311  2013
# 20     Piccadilly Gate Store Street Manchester M   ...      1  50065530  2019
# 21       Little MarVals    URC Hall  Old Pinn Lane ...      0   2556312  2016
# 22   Untitled for s provisionEY      Unique Referen...      0   1047517  2015
# 23   School report   Hallcroft Infant and Nursery S...      1   2580455  2016
# 24     Piccadilly Gate Store Street Manchester M   ...      1   2761465  2018
# 25    for s provisionUnique Reference Number EY    ...      0   1084621  2009
# 26    EYL     V                    Complaint about ...      1   2504468  2018
# 27    School report    The Nettleham Church of Engl...      0   2367609  2018
# 28   UntitledWley Church of England PrimarySchool  ...      0    930315  2011
# 29     CfBT Inspection Services Suite    West Lancs...      1   2403342  2018
# ..                                                 ...    ...       ...   ...
# 438         PDFINSPECTION REPORT         WILMINGTON...      0    793181  2008
# 439      Avenue Kids Club  A K C      The Nexus Cen...      0   2753437  2018
# 440  School report  Moulton Chapel Primary School  ...      0   2546225  2016
# 441      FullStaffordshe LEA ReREINSPECTION REPORT ...      1    874505  2010
# 445      7    29   22          3        203         False           False
# 446     10    44   31          2        304          True           False
# 447      2     6    3          1         34         False           False
# 448      1     3   14          2         14         False           False
# 449      1     1    7          4          7         False           False
# 450      5    19   15          6        136         False           False
# 451      6    25   22          2        174         False           False
# 452      5    20   17          3        138         False           False
# 453      7    27    1          2        182         False            True
# 454      5    19    7          2        128         False           False
# 455      6    26   30          2        181          True           False
# 456      4    17   26          4        116         False           False
# 457      1     3   17          5         17         False           False
# 458      1     3   20          4         20         False           False
# 459      4    17   25          3        115         False           False
# 460     12    51   19          2        354         False           False
# 461      2     9   28          1         59         False           False
# 462      1     4   22          0         22         False           False
# 463     11    44    1          1        305         False            True
# 464      6    23    6          2        157         False           False
# 465      2     7   12          3         43         False           False
# 466      4    17   26          4        116         False           False
# 467      3    11   14          0         74         False           False
#
#      Is_quarter_end  Is_quarter_start  Is_year_end  Is_year_start     Elapsed
# 0             False             False        False          False  1325721600
# 1             False             False        False          False  1317254400
# 2             False             False        False          False  1352419200
# 3             False             False        False          False  1472169600
# 4             False             False        False          False  1228867200
# 5             False             False        False          False  1548979200
# 6             False             False        False          False  1394150400
# 7             False             False        False          False  1526428800
# 8             False             False        False          False  1501200000
# 9             False             False        False          False  1109203200
# 10            False             False        False          False  1526428800
# 11            False             False        False          False  1540339200
# 12            False             False        False          False  1464220800
# 13            False             False        False          False  1477008000
# 14            False             False        False          False  1322697600
# 15            False             False        False          False  1430956800
# 16            False             False        False          False  1433289600
# 17            False             False        False          False  1263254400
# 18            False             False        False          False  1516320000
# 19            False             False        False          False  1366588800
# 20            False             False        False          False  1551744000
# 21            False             False        False          False  1457913600
# 22            False             False        False          False  1423526400
# 23            False             False        False          False  1465257600
# 24            False             False        False          False  1517875200
# 25            False             False        False          False  1232496000
# 26            False             False        False          False  1516752000
# 27            False             False        False          False  1519862400
# 28            False             False        False          False  1317081600
# 29            False             False        False          False  1536796800
# ..              ...               ...          ...            ...         ...
# 438           False             False        False          False  1212624000
# 439           False             False        False          False  1516665600
# 440           False             False        False          False  1453852800
# 441           False             False        False          False  1268179200
# 442           False             False        False          False  1359504000
# 443           False             False        False          False  1466035200
# 444           False             False        False          False  1406073600
# 445           False             False        False          False  1279756800
# 446           False             False        False          False  1540944000
# 447           False             False        False          False  1422921600
# 448           False             False        False          False  1421193600
# 449           False             False        False          False  1294358400
# 450           False             False        False          False  1463270400
# 451           False             False        False          False  1466553600
# 452           False             False        False          False  1337212800
# 453           False              True        False          False  1246406400
# 454           False             False        False          False  1210118400
# 455            True             False        False          False  1277856000
# 456           False             False        False          False  1366934400
# 457           False             False        False          False  1421452800
# 458           False             False        False          False  1484870400
# 459           False             False        False          False  1366848000
# 460           False             False        False          False  1355875200
# 461           False             False        False          False  1330387200
# 462           False             False        False          False  1516579200
# 463           False             False        False          False  1320105600
# 464           False             False        False          False  1528243200
# 465           False             False        False          False  1423699200
# 466           False             False        False          False  1556236800
# 467           False             False        False          False  1457913600
#
# [468 rows x 18 columns]

# %%
list(train.columns)
# Out:
# ['Unnamed: 0',
#  'school',
#  'text',
#  'label',
#  'file',
#  'Year',
#  'Month',
#  'Week',
#  'Day',
#  'Dayofweek',
#  'Dayofyear',
#  'Is_month_end',
#  'Is_month_start',
#  'Is_quarter_end',
#  'Is_quarter_start',
#  'Is_year_end',
#  'Is_year_start',
#  'Elapsed']

# %%
train = train.sort_values(['Elapsed'])
test = test.sort_values(['Elapsed'])

# %%
cat_names = ['school','Is_month_end','Is_month_start','Is_quarter_end','Is_quarter_start','Is_year_end','Is_year_start','Year','Month','Week','Day','Dayofweek','Dayofyear']
cont_names = ['file','Elapsed']
txt_cols = ['text']
dep_var = ['label'] 
procs = [FillMissing, Categorify, Normalize]

# %%
len(cat_names) + len(cont_names) + 2 == train.shape[1]
# Out:
# False

# %%
train_idxs,val_idxs = get_val_idxs(train,n_splits=20)
train_idxs,val_idxs
train_idxs.shape,val_idxs.shape
# Out:
# (array([   0,    1,    2,    3, ..., 1822, 1823, 1824, 1825]),
#  array([  29,   65,  109,  111, ..., 1782, 1792, 1802, 1813]))
# ((1734,), (92,))

# %%
def get_tabular_databunch(train_df,bs=100,val_idxs=val_idxs,path = './'):
    return (TabularList.from_df(train_df, cat_names, cont_names, procs=procs, path=path)
                            .split_by_idx(val_idxs)
                            .label_from_df(cols=dep_var,label_cls=CategoryList)
                            .add_test(TabularList.from_df(test, cat_names, cont_names, txt_cols,path='./'))
                            .databunch(bs=bs))

# %%
def get_text_databunch(train_df,bs=100,val_idxs=val_idxs,path = './'):
    data_lm = load_data(path, 'data_lm.pkl', bs=bs)
    return (TextList.from_df(train_df, cols = txt_cols[0], vocab=data_lm.vocab, path=path)
                            .split_by_idx(val_idxs)
                            .label_from_df(cols=dep_var,label_cls=CategoryList)
                            .databunch(bs=bs))

# %%
def get_tabular_learner(data,params,seed=42):
    return tabular_learner(data,metrics=accuracy,**params)

# %%
def get_text_learner(data,params,seed=42):

    learn = text_classifier_learner(data,AWD_LSTM,metrics=accuracy,**params)
    
    # language model trained in 'mercari language model' notebook
    
    #TODO: new AWD_LSTM structure causing mismatch. Retrain language model!
    encoder_name = 'bs60-awdlstm-enc-stage2'
    learn.load_encoder(encoder_name) 
    return learn

# %%
def get_databunches(bs=64,path= './'):
    # get tabtext databunch, tabular databunch (for tabular model) and text databunch (for text model)
    tab_db = get_tabular_databunch(train[cat_names + cont_names + dep_var])
    text_db = get_text_databunch(train[txt_cols +dep_var])
    
    train_ds = ConcatDataset(tab_db.train_ds.x, text_db.train_ds.x, tab_db.train_ds.y)
    valid_ds = ConcatDataset(tab_db.valid_ds.x, text_db.valid_ds.x, tab_db.valid_ds.y)
    
    train_sampler = SortishSampler(text_db.train_ds.x, key=lambda t: len(text_db.train_ds[t][0].data), bs=bs//2)
    valid_sampler = SortSampler(text_db.valid_ds.x, key=lambda t: len(text_db.valid_ds[t][0].data))

#     train_dl = DataLoader(train_ds, bs//2, sampler=train_sampler)
    train_dl = DataLoader(train_ds, bs//2, shuffle=True) # shuffle=True; Error: sampler option mutually exclusive with shuffle
    valid_dl = DataLoader(valid_ds, bs, shuffle=True) #sampler=valid_sampler
    data = DataBunch(train_dl, valid_dl, device=defaults.device, collate_fn=tabtext_collate, path=path)
    return data,tab_db,text_db

# %%
data,tab_db,text_db = get_databunches(bs=64)

# %%
tab_params={
    'layers':[500],
    'emb_drop': 0.,
    'y_range': [0,6],
    'use_bn': True,    
    }

text_params={
    #     'lin_ftrs':[1000],
    #     'ps': [0.001,0,0],
        'bptt':70,
        'max_len':20*70,
        'drop_mult': 1., 
    #     'use_bn': True,    
    }

# %%
tab_learner = get_tabular_learner(tab_db,tab_params)
text_learner = get_text_learner(text_db,text_params)

# %%
tab_learner.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(1676, 102)
#     (1): Embedding(3, 3)
#     (2): Embedding(3, 3)
#     (3): Embedding(3, 3)
#     (4): Embedding(3, 3)
#     (5): Embedding(3, 3)
#     (6): Embedding(2, 2)
#     (7): Embedding(19, 8)
#     (8): Embedding(13, 7)
#     (9): Embedding(53, 15)
#     (10): Embedding(32, 11)
#     (11): Embedding(8, 5)
#     (12): Embedding(354, 43)
#   )
#   (emb_drop): Dropout(p=0.0)
#   (bn_cont): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=210, out_features=500, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Linear(in_features=500, out_features=2, bias=True)
#   )
# )

# %%
text_learner.model
# Out:
# SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(60004, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(60004, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1150, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1150, 1150, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1150, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.4)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# )

# %%
lin_layers=[500]
ps=[0.]
# 50 is the default lin_ftrs in AWD_LSTM
lin_layers[-1]+= 50 if 'lin_ftrs' not in text_params else text_params['lin_ftrs']

# %%
learner = get_tabtext_learner(data,tab_learner,text_learner,lin_layers ,ps)

# %%
learner.model
# Out:
# ConcatModel(
#   (mod_tab): TabularModel(
#     (embeds): ModuleList(
#       (0): Embedding(1676, 102)
#       (1): Embedding(3, 3)
#       (2): Embedding(3, 3)
#       (3): Embedding(3, 3)
#       (4): Embedding(3, 3)
#       (5): Embedding(3, 3)
#       (6): Embedding(2, 2)
#       (7): Embedding(19, 8)
#       (8): Embedding(13, 7)
#       (9): Embedding(53, 15)
#       (10): Embedding(32, 11)
#       (11): Embedding(8, 5)
#       (12): Embedding(354, 43)
#     )
#     (emb_drop): Dropout(p=0.0)
#     (bn_cont): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (layers): Sequential(
#       (0): Linear(in_features=210, out_features=500, bias=True)
#       (1): ReLU(inplace)
#     )
#   )
#   (mod_nlp): SequentialRNN(
#     (0): MultiBatchEncoder(
#       (module): AWD_LSTM(
#         (encoder): Embedding(60004, 400, padding_idx=1)
#         (encoder_dp): EmbeddingDropout(
#           (emb): Embedding(60004, 400, padding_idx=1)
#         )
#         (rnns): ModuleList(
#           (0): WeightDropout(
#             (module): LSTM(400, 1150, batch_first=True)
#           )
#           (1): WeightDropout(
#             (module): LSTM(1150, 1150, batch_first=True)
#           )
#           (2): WeightDropout(
#             (module): LSTM(1150, 400, batch_first=True)
#           )
#         )
#         (input_dp): RNNDropout()
#         (hidden_dps): ModuleList(
#           (0): RNNDropout()
#           (1): RNNDropout()
#           (2): RNNDropout()
#         )
#       )
#     )
#     (1): PoolingLinearClassifier(
#       (layers): Sequential(
#         (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Dropout(p=0.4)
#         (2): Linear(in_features=1200, out_features=50, bias=True)
#         (3): ReLU(inplace)
#       )
#     )
#   )
#   (layers): Sequential(
#     (0): BatchNorm1d(550, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Linear(in_features=550, out_features=2, bias=True)
#   )
# )

# %%
len(learner.layer_groups)
learner.layer_groups
# Out:
# 5
# [Sequential(
#    (0): Embedding(60004, 400, padding_idx=1)
#    (1): Embedding(60004, 400, padding_idx=1)
#  ), Sequential(
#    (0): LSTM(400, 1150, batch_first=True)
#    (1): ParameterModule()
#    (2): RNNDropout()
#  ), Sequential(
#    (0): LSTM(1150, 1150, batch_first=True)
#    (1): ParameterModule()
#    (2): RNNDropout()
#  ), Sequential(
#    (0): LSTM(1150, 400, batch_first=True)
#    (1): ParameterModule()
#    (2): RNNDropout()
#  ), Sequential(
#    (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (1): Dropout(p=0.4)
#    (2): Linear(in_features=1200, out_features=50, bias=True)
#    (3): ReLU(inplace)
#    (4): Embedding(1676, 102)
#    (5): Embedding(3, 3)
#    (6): Embedding(3, 3)
#    (7): Embedding(3, 3)
#    (8): Embedding(3, 3)
#    (9): Embedding(3, 3)
#    (10): Embedding(2, 2)
#    (11): Embedding(19, 8)
#    (12): Embedding(13, 7)
#    (13): Embedding(53, 15)
#    (14): Embedding(32, 11)
#    (15): Embedding(8, 5)
#    (16): Embedding(354, 43)
#    (17): Dropout(p=0.0)
#    (18): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (19): Linear(in_features=210, out_features=500, bias=True)
#    (20): ReLU(inplace)
#    (21): BatchNorm1d(550, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (22): Linear(in_features=550, out_features=2, bias=True)
#  )]

# %%
learner.freeze()
learner.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.recorder.plot(skip_end=1)

# %%
learner.fit_one_cycle(5, 1e-2, moms=(0.8,0.7))
# Out:
# Total time: 2:04:16 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.615952</td>
#       <td>0.554054</td>
#       <td>0.760870</td>
#       <td>26:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.421164</td>
#       <td>0.577062</td>
#       <td>0.771739</td>
#       <td>25:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.205649</td>
#       <td>0.660361</td>
#       <td>0.739130</td>
#       <td>23:42</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.091812</td>
#       <td>0.663263</td>
#       <td>0.739130</td>
#       <td>24:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.041033</td>
#       <td>0.674322</td>
#       <td>0.728261</td>
#       <td>24:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.recorder.plot_losses()

# %%
learner.save('tabtext_learner')

# %%
learner.load('tabtext_learner')
# Out:
# Learner(data=DataBunch;
#
# Train: <fastai_tabtext2.ConcatDataset object at 0x7f5805127d30>;
#
# Valid: <fastai_tabtext2.ConcatDataset object at 0x7f5805127f28>;
#
# Test: None, model=ConcatModel(
#   (mod_tab): TabularModel(
#     (embeds): ModuleList(
#       (0): Embedding(1676, 102)
#       (1): Embedding(3, 3)
#       (2): Embedding(3, 3)
#       (3): Embedding(3, 3)
#       (4): Embedding(3, 3)
#       (5): Embedding(3, 3)
#       (6): Embedding(2, 2)
#       (7): Embedding(19, 8)
#       (8): Embedding(13, 7)
#       (9): Embedding(53, 15)
#       (10): Embedding(32, 11)
#       (11): Embedding(8, 5)
#       (12): Embedding(354, 43)
#     )
#     (emb_drop): Dropout(p=0.0)
#     (bn_cont): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (layers): Sequential(
#       (0): Linear(in_features=210, out_features=500, bias=True)
#       (1): ReLU(inplace)
#     )
#   )
#   (mod_nlp): SequentialRNN(
#     (0): MultiBatchEncoder(
#       (module): AWD_LSTM(
#         (encoder): Embedding(60004, 400, padding_idx=1)
#         (encoder_dp): EmbeddingDropout(
#           (emb): Embedding(60004, 400, padding_idx=1)
#         )
#         (rnns): ModuleList(
#           (0): WeightDropout(
#             (module): LSTM(400, 1150, batch_first=True)
#           )
#           (1): WeightDropout(
#             (module): LSTM(1150, 1150, batch_first=True)
#           )
#           (2): WeightDropout(
#             (module): LSTM(1150, 400, batch_first=True)
#           )
#         )
#         (input_dp): RNNDropout()
#         (hidden_dps): ModuleList(
#           (0): RNNDropout()
#           (1): RNNDropout()
#           (2): RNNDropout()
#         )
#       )
#     )
#     (1): PoolingLinearClassifier(
#       (layers): Sequential(
#         (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Dropout(p=0.4)
#         (2): Linear(in_features=1200, out_features=50, bias=True)
#         (3): ReLU(inplace)
#       )
#     )
#   )
#   (layers): Sequential(
#     (0): BatchNorm1d(550, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Linear(in_features=550, out_features=2, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f580f58fae8>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Embedding(60004, 400, padding_idx=1)
#   (1): Embedding(60004, 400, padding_idx=1)
# ), Sequential(
#   (0): LSTM(400, 1150, batch_first=True)
#   (1): ParameterModule()
#   (2): RNNDropout()
# ), Sequential(
#   (0): LSTM(1150, 1150, batch_first=True)
#   (1): ParameterModule()
#   (2): RNNDropout()
# ), Sequential(
#   (0): LSTM(1150, 400, batch_first=True)
#   (1): ParameterModule()
#   (2): RNNDropout()
# ), Sequential(
#   (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (1): Dropout(p=0.4)
#   (2): Linear(in_features=1200, out_features=50, bias=True)
#   (3): ReLU(inplace)
#   (4): Embedding(1676, 102)
#   (5): Embedding(3, 3)
#   (6): Embedding(3, 3)
#   (7): Embedding(3, 3)
#   (8): Embedding(3, 3)
#   (9): Embedding(3, 3)
#   (10): Embedding(2, 2)
#   (11): Embedding(19, 8)
#   (12): Embedding(13, 7)
#   (13): Embedding(53, 15)
#   (14): Embedding(32, 11)
#   (15): Embedding(8, 5)
#   (16): Embedding(354, 43)
#   (17): Dropout(p=0.0)
#   (18): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): Linear(in_features=210, out_features=500, bias=True)
#   (20): ReLU(inplace)
#   (21): BatchNorm1d(550, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Linear(in_features=550, out_features=2, bias=True)
# )], add_time=True, silent=None)

# %%
learner.fit_one_cycle(2, slice(1e-2), moms=(0.8, 0.7))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='55', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       27.27% [15/55 06:43<17:55 0.0113]
#     </div>

# %%
learner.save('trained_model2_jul25')

# %%
learner.load('trained_model2_jul25')

# %%
learner.freeze_to(-2)
learner.fit_one_cycle(1, slice(1e-2/(2.6**4),1e-2), moms=(0.8,0.7))

# %%
learner.save('trained_model3_jul25')

# %%
learner.load('trained_model3_jul25');

# %%
learner.freeze_to(-2)
learner.fit_one_cycle(2, 3e-2, moms=(0.8,0.7))

# %%
learner.save('trained_model4_jul25')
learner.load('trained_model4_jul25')

# %%
learner.freeze_to(-2)
learner.fit_one_cycle(4, slice(1e-2/(2.6**4),1e-2), moms=(0.8,0.7))

# %%
test.loc[384]

# %%
pred, raw_pred = predict_one_item(learner, test.loc[384], tab_db, text_db)

# %%
pred,raw_pred

# %%
pred, raw_pred = predict_one_item(learner, test.loc[18797], tab_db, text_db)

# %%
pred, raw_pred

# %%
pred, raw_pred = predict_one_item(learner, test.loc[65889], tab_db, text_db)

# %%
pred, raw_pred

# %%
pickle.dump(learner.model.state_dict(),open('weights_jul25.pkl','wb'))

# %%
text_learner.export('text_learner_jul25.pkl')

# %%
tab_learner.export('tab_learner_jul25.pkl')
